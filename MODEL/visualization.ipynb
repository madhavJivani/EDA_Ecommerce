# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\Dell\Desktop\Programs\Scaraping\py-scraping\Combined_csvs\final_cleaned_smartphones2.csv')

# %%
df.head(10)
# Out:
#                        product_name  rating_stars  number_of_reviews  \
# 0              Apple iPhone 15 () -           4.5                217
# 1         Apple iPhone 15 () - Pink           4.4                213
# 2    Apple iPhone 13 () - Starlight           4.5               7819
# 3     Apple iPhone 13 () - Midnight           4.5               6614
# 4         Apple iPhone 13 () - Pink           4.5               3136
# 5              Apple iPhone 16 () -           4.5                 79
# 6              Apple iPhone 15 () -           4.5                637
# 7  Apple iPhone 16 () - Ultramarine           4.5                 79
# 8         Apple iPhone 15 Plus () -           4.6                236
# 9              Apple iPhone 14 () -           4.5               1640
#
#    bought_last_month  discounted_mrp  original_mrp  discount%  free_delivery  \
# 0                200         65900.0         79900       18.0              0
# 1                100         65900.0         79600       17.0              0
# 2               5000         45490.0         59900       24.0              0
# 3               5000         45490.0         59600       24.0              0
# 4               5000         45490.0         59900       24.0              0
# 5                500         78400.0         79900        2.0              0
# 6                500         65900.0         79600       17.0              0
# 7                500         77900.0         79900        3.0              0
# 8                400         69900.0         89600       22.0              0
# 9                200         54900.0         69600       21.0              0
#
#    brand         product        color  storage_in_GB  RAM_in_GB
# 0  apple       iPhone 15        Green            128          6
# 1  apple       iPhone 15         Pink            128          6
# 2  apple       iPhone 13    Starlight            128          6
# 3  apple       iPhone 13     Midnight            128          6
# 4  apple       iPhone 13         Pink            128          6
# 5  apple       iPhone 16        Black            128          8
# 6  apple       iPhone 15         Blue            128          6
# 7  apple       iPhone 16  Ultramarine            128          8
# 8  apple  iPhone 15 Plus         Blue            128          6
# 9  apple       iPhone 14         Blue            128          6

# %%
df.dtypes
# Out:
# product_name          object
# rating_stars         float64
# number_of_reviews      int64
# bought_last_month      int64
# discounted_mrp       float64
# original_mrp           int64
# discount%            float64
# free_delivery          int64
# brand                 object
# product               object
# color                 object
# storage_in_GB          int64
# RAM_in_GB              int64
# dtype: object

# %%
numeric=df.select_dtypes(exclude=['object'])
numeric.corr()

plt.figure(figsize=(8,6))
sns.heatmap(numeric.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='brand', y='original_mrp', data=df)
# plt.xticks(rotation=90)
plt.title('Box Plot of Current Price by Brand')
plt.show()

# %%
# Group by 'Brand' and plot correlation heatmap for each brand
for brand_name, group_data in df.groupby('brand'):
    # Select only numeric columns within each brand group
    numeric_data = group_data.select_dtypes(exclude=['object'])
    
    # Calculate correlation matrix
    corr_matrix = numeric_data.corr()
    
    # Plot heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title(f'Correlation Heatmap for {brand_name}')
    plt.show()

# %%
df['brand'].unique()
# Out:
# array(['apple', 'iphone', 'oneplus', 'oppo', 'realme', 'samsung', 'vivo',
#        'xiaomi', 'redmi'], dtype=object)

# %%
print(df[df['brand'] == "apple"]["free_delivery"].unique())
print(df[df['brand'] == "iphone"]["free_delivery"].unique())
print(df[df['brand'] == "iphone"]["bought_last_month"].unique())
print(df[df['brand'] == "iphone"]["storage_in_GB"].unique())
# Out:
# [0]
# [0]
# [0]
# [128]

# %%
# Replace 'iphone' with 'apple' and 'redmi' with 'xiaomi'
df['brand'] = df['brand'].replace({'iphone': 'apple', 'redmi': 'xiaomi'})

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='brand', y='original_mrp', data=df)
# plt.xticks(rotation=90)
plt.title('Box Plot of Current Price by Brand')
plt.show()

# %%
# Group by 'Brand' and plot correlation heatmap for each brand
for brand_name, group_data in df.groupby('brand'):
    # Select only numeric columns within each brand group
    numeric_data = group_data.select_dtypes(exclude=['object'])
    
    # Calculate correlation matrix
    corr_matrix = numeric_data.corr()
    
    # Plot heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title(f'Correlation Heatmap for {brand_name}')
    plt.show()

# %%
# Group by 'Brand' and plot correlation heatmap for each brand
for brand_name, group_data in df.groupby('brand'):
    # Select only numeric columns within each brand group
    numeric_data = group_data.select_dtypes(exclude=['object'])
    
    # Calculate correlation matrix
    corr_matrix = numeric_data.corr()

    print(corr_matrix)
# Out:
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.150815           0.107047
# number_of_reviews      0.150815           1.000000           0.890905
# bought_last_month      0.107047           0.890905           1.000000
# discounted_mrp        -0.333294          -0.328354          -0.340486
# original_mrp          -0.328423          -0.297286          -0.326269
# discount%              0.138103           0.261271           0.206642
# free_delivery               NaN                NaN                NaN
# storage_in_GB          0.003376          -0.259186          -0.216527
# RAM_in_GB             -0.221220          -0.178777          -0.106207
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars            -0.333294     -0.328423   0.138103            NaN
# number_of_reviews       -0.328354     -0.297286   0.261271            NaN
# bought_last_month       -0.340486     -0.326269   0.206642            NaN
# discounted_mrp           1.000000      0.951876  -0.420077            NaN
# original_mrp             0.951876      1.000000  -0.134263            NaN
# discount%               -0.420077     -0.134263   1.000000            NaN
# free_delivery                 NaN           NaN        NaN            NaN
# storage_in_GB            0.273359      0.253476  -0.089145            NaN
# RAM_in_GB                0.288026      0.041367  -0.830700            NaN
#
#                    storage_in_GB  RAM_in_GB
# rating_stars            0.003376  -0.221220
# number_of_reviews      -0.259186  -0.178777
# bought_last_month      -0.216527  -0.106207
# discounted_mrp          0.273359   0.288026
# original_mrp            0.253476   0.041367
# discount%              -0.089145  -0.830700
# free_delivery                NaN        NaN
# storage_in_GB           1.000000   0.098067
# RAM_in_GB               0.098067   1.000000
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.149103           0.275941
# number_of_reviews      0.149103           1.000000          -0.205209
# bought_last_month      0.275941          -0.205209           1.000000
# discounted_mrp         0.342438          -0.218724          -0.298549
# original_mrp           0.132780          -0.241725          -0.361111
# discount%             -0.668499          -0.092078          -0.201264
# free_delivery          0.427775          -0.261883           0.680761
# storage_in_GB          0.329273          -0.254606          -0.249079
# RAM_in_GB              0.247451          -0.281587          -0.280371
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars             0.342438      0.132780  -0.668499       0.427775
# number_of_reviews       -0.218724     -0.241725  -0.092078      -0.261883
# bought_last_month       -0.298549     -0.361111  -0.201264       0.680761
# discounted_mrp           1.000000      0.932958  -0.274732       0.175968
# original_mrp             0.932958      1.000000   0.065607       0.084892
# discount%               -0.274732      0.065607   1.000000      -0.304309
# free_delivery            0.175968      0.084892  -0.304309       1.000000
# storage_in_GB            0.831069      0.744869  -0.313655       0.177392
# RAM_in_GB                0.795980      0.759536  -0.108514       0.159541
#
#                    storage_in_GB  RAM_in_GB
# rating_stars            0.329273   0.247451
# number_of_reviews      -0.254606  -0.281587
# bought_last_month      -0.249079  -0.280371
# discounted_mrp          0.831069   0.795980
# original_mrp            0.744869   0.759536
# discount%              -0.313655  -0.108514
# free_delivery           0.177392   0.159541
# storage_in_GB           1.000000   0.774955
# RAM_in_GB               0.774955   1.000000
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.181377           0.192344
# number_of_reviews      0.181377           1.000000          -0.167151
# bought_last_month      0.192344          -0.167151           1.000000
# discounted_mrp         0.055470           0.029592           0.236907
# original_mrp          -0.024652          -0.031441           0.079098
# discount%             -0.198375          -0.184764          -0.385667
# free_delivery          0.031980          -0.300685           0.564700
# storage_in_GB         -0.087224          -0.048626           0.244819
# RAM_in_GB              0.021061          -0.047009           0.159526
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars             0.055470     -0.024652  -0.198375       0.031980
# number_of_reviews        0.029592     -0.031441  -0.184764      -0.300685
# bought_last_month        0.236907      0.079098  -0.385667       0.564700
# discounted_mrp           1.000000      0.920211  -0.491921       0.192214
# original_mrp             0.920211      1.000000  -0.136536      -0.043320
# discount%               -0.491921     -0.136536   1.000000      -0.580241
# free_delivery            0.192214     -0.043320  -0.580241       1.000000
# storage_in_GB            0.746875      0.723950  -0.322257       0.094238
# RAM_in_GB                0.876551      0.917222  -0.247179       0.065620
#
#                    storage_in_GB  RAM_in_GB
# rating_stars           -0.087224   0.021061
# number_of_reviews      -0.048626  -0.047009
# bought_last_month       0.244819   0.159526
# discounted_mrp          0.746875   0.876551
# original_mrp            0.723950   0.917222
# discount%              -0.322257  -0.247179
# free_delivery           0.094238   0.065620
# storage_in_GB           1.000000   0.777587
# RAM_in_GB               0.777587   1.000000
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.108246           0.055347
# number_of_reviews      0.108246           1.000000           0.420453
# bought_last_month      0.055347           0.420453           1.000000
# discounted_mrp         0.434970           0.007966          -0.396229
# original_mrp           0.330092           0.024499          -0.463536
# discount%             -0.516937           0.044119           0.016288
# free_delivery         -0.143646           0.203048           0.467738
# storage_in_GB          0.097737          -0.117887          -0.378629
# RAM_in_GB              0.208838          -0.235749          -0.432808
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars             0.434970      0.330092  -0.516937      -0.143646
# number_of_reviews        0.007966      0.024499   0.044119       0.203048
# bought_last_month       -0.396229     -0.463536   0.016288       0.467738
# discounted_mrp           1.000000      0.955876  -0.595724      -0.319296
# original_mrp             0.955876      1.000000  -0.344087      -0.332437
# discount%               -0.595724     -0.344087   1.000000       0.147461
# free_delivery           -0.319296     -0.332437   0.147461       1.000000
# storage_in_GB            0.771597      0.765508  -0.372869      -0.307664
# RAM_in_GB                0.719180      0.750938  -0.295050      -0.403945
#
#                    storage_in_GB  RAM_in_GB
# rating_stars            0.097737   0.208838
# number_of_reviews      -0.117887  -0.235749
# bought_last_month      -0.378629  -0.432808
# discounted_mrp          0.771597   0.719180
# original_mrp            0.765508   0.750938
# discount%              -0.372869  -0.295050
# free_delivery          -0.307664  -0.403945
# storage_in_GB           1.000000   0.736676
# RAM_in_GB               0.736676   1.000000
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.181727           0.092762
# number_of_reviews      0.181727           1.000000          -0.031775
# bought_last_month      0.092762          -0.031775           1.000000
# discounted_mrp         0.137435          -0.171743          -0.329741
# original_mrp           0.083450          -0.006776          -0.383613
# discount%              0.006315           0.524688          -0.163607
# free_delivery         -0.023494          -0.063603           0.052521
# storage_in_GB          0.110639          -0.226853          -0.294095
# RAM_in_GB              0.151761           0.132067          -0.407925
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars             0.137435      0.083450   0.006315      -0.023494
# number_of_reviews       -0.171743     -0.006776   0.524688      -0.063603
# bought_last_month       -0.329741     -0.383613  -0.163607       0.052521
# discounted_mrp           1.000000      0.912713  -0.062643       0.095206
# original_mrp             0.912713      1.000000   0.315701       0.131919
# discount%               -0.062643      0.315701   1.000000       0.067258
# free_delivery            0.095206      0.131919   0.067258       1.000000
# storage_in_GB            0.715412      0.654692  -0.046207       0.141308
# RAM_in_GB                0.626700      0.632793   0.083339       0.080185
#
#                    storage_in_GB  RAM_in_GB
# rating_stars            0.110639   0.151761
# number_of_reviews      -0.226853   0.132067
# bought_last_month      -0.294095  -0.407925
# discounted_mrp          0.715412   0.626700
# original_mrp            0.654692   0.632793
# discount%              -0.046207   0.083339
# free_delivery           0.141308   0.080185
# storage_in_GB           1.000000   0.501958
# RAM_in_GB               0.501958   1.000000
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.086702           0.113810
# number_of_reviews      0.086702           1.000000          -0.225103
# bought_last_month      0.113810          -0.225103           1.000000
# discounted_mrp         0.397827          -0.190599          -0.129362
# original_mrp           0.424268          -0.187410          -0.135013
# discount%             -0.046394           0.462978          -0.047534
# free_delivery         -0.278249          -0.013341          -0.024493
# storage_in_GB          0.437427          -0.147232          -0.065883
# RAM_in_GB              0.345908          -0.144938          -0.098995
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars             0.397827      0.424268  -0.046394      -0.278249
# number_of_reviews       -0.190599     -0.187410   0.462978      -0.013341
# bought_last_month       -0.129362     -0.135013  -0.047534      -0.024493
# discounted_mrp           1.000000      0.995006  -0.628909       0.115875
# original_mrp             0.995006      1.000000  -0.595850       0.114753
# discount%               -0.628909     -0.595850   1.000000      -0.044241
# free_delivery            0.115875      0.114753  -0.044241       1.000000
# storage_in_GB            0.767470      0.779139  -0.566251      -0.120450
# RAM_in_GB                0.819826      0.843071  -0.638612       0.017666
#
#                    storage_in_GB  RAM_in_GB
# rating_stars            0.437427   0.345908
# number_of_reviews      -0.147232  -0.144938
# bought_last_month      -0.065883  -0.098995
# discounted_mrp          0.767470   0.819826
# original_mrp            0.779139   0.843071
# discount%              -0.566251  -0.638612
# free_delivery          -0.120450   0.017666
# storage_in_GB           1.000000   0.759345
# RAM_in_GB               0.759345   1.000000
#                    rating_stars  number_of_reviews  bought_last_month  \
# rating_stars           1.000000           0.185799          -0.017289
# number_of_reviews      0.185799           1.000000           0.006857
# bought_last_month     -0.017289           0.006857           1.000000
# discounted_mrp         0.184016          -0.238900          -0.229736
# original_mrp           0.238943          -0.218792          -0.266227
# discount%              0.129910           0.011578          -0.152502
# free_delivery         -0.108575          -0.085594          -0.014457
# storage_in_GB          0.184579          -0.212520          -0.158926
# RAM_in_GB              0.164158          -0.261693          -0.256037
#
#                    discounted_mrp  original_mrp  discount%  free_delivery  \
# rating_stars             0.184016      0.238943   0.129910      -0.108575
# number_of_reviews       -0.238900     -0.218792   0.011578      -0.085594
# bought_last_month       -0.229736     -0.266227  -0.152502      -0.014457
# discounted_mrp           1.000000      0.888451  -0.253459       0.047474
# original_mrp             0.888451      1.000000   0.173415       0.074413
# discount%               -0.253459      0.173415   1.000000       0.018191
# free_delivery            0.047474      0.074413   0.018191       1.000000
# storage_in_GB            0.858444      0.716561  -0.282945      -0.004365
# RAM_in_GB                0.753554      0.621105  -0.343828       0.012608
#
#                    storage_in_GB  RAM_in_GB
# rating_stars            0.184579   0.164158
# number_of_reviews      -0.212520  -0.261693
# bought_last_month      -0.158926  -0.256037
# discounted_mrp          0.858444   0.753554
# original_mrp            0.716561   0.621105
# discount%              -0.282945  -0.343828
# free_delivery          -0.004365   0.012608
# storage_in_GB           1.000000   0.801758
# RAM_in_GB               0.801758   1.000000

# %%
# Initialize an empty dictionary to store sorted correlation results for each brand
sorted_correlations = {}

# Iterate over each brand
for brand_name, brand_data in df.groupby('brand'):
    # Drop irrelevant columns, such as 'productname', 'product', and 'discounted_mrp'
    features = brand_data.drop(columns=['product_name', 'product', 'discounted_mrp'])
    
    # Ensure we're only working with numeric data
    numeric_data = features.select_dtypes(include=['float64', 'int64'])
    
    # Compute correlation matrix
    corr_matrix = numeric_data.corr()
    
    # Extract correlation values for 'discount%' and 'free_delivery' with all other columns
    target_correlations = corr_matrix[['discount%', 'free_delivery']]
    
    # Sort each target variable's correlation values in descending order
    sorted_discount_corr = target_correlations['discount%'].abs().sort_values(ascending=False)
    sorted_free_delivery_corr = target_correlations['free_delivery'].abs().sort_values(ascending=False)
    
    # Store sorted correlations in the dictionary for each brand
    sorted_correlations[brand_name] = {
        'discount%': sorted_discount_corr,
        'free_delivery': sorted_free_delivery_corr
    }
    
    # Print sorted correlation values for each brand
    print(f"\n--- Correlations for Brand: {brand_name} ---")
    print("\nCorrelations with 'discount%' (sorted in descending order):")
    print(sorted_discount_corr)
    print("\nCorrelations with 'free_delivery' (sorted in descending order):")
    print(sorted_free_delivery_corr)
# Out:
# --- Correlations for Brand: apple ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# RAM_in_GB            0.830700
# number_of_reviews    0.261271
# bought_last_month    0.206642
# rating_stars         0.138103
# original_mrp         0.134263
# storage_in_GB        0.089145
# free_delivery             NaN
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# rating_stars        NaN
# number_of_reviews   NaN
# bought_last_month   NaN
# original_mrp        NaN
# discount%           NaN
# free_delivery       NaN
# storage_in_GB       NaN
# RAM_in_GB           NaN
# Name: free_delivery, dtype: float64
#
# --- Correlations for Brand: oneplus ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# rating_stars         0.668499
# storage_in_GB        0.313655
# free_delivery        0.304309
# bought_last_month    0.201264
# RAM_in_GB            0.108514
# number_of_reviews    0.092078
# original_mrp         0.065607
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# free_delivery        1.000000
# bought_last_month    0.680761
# rating_stars         0.427775
# discount%            0.304309
# number_of_reviews    0.261883
# storage_in_GB        0.177392
# RAM_in_GB            0.159541
# original_mrp         0.084892
# Name: free_delivery, dtype: float64
#
# --- Correlations for Brand: oppo ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# free_delivery        0.580241
# bought_last_month    0.385667
# storage_in_GB        0.322257
# RAM_in_GB            0.247179
# rating_stars         0.198375
# number_of_reviews    0.184764
# original_mrp         0.136536
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# free_delivery        1.000000
# discount%            0.580241
# bought_last_month    0.564700
# number_of_reviews    0.300685
# storage_in_GB        0.094238
# RAM_in_GB            0.065620
# original_mrp         0.043320
# rating_stars         0.031980
# Name: free_delivery, dtype: float64
#
# --- Correlations for Brand: realme ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# rating_stars         0.516937
# storage_in_GB        0.372869
# original_mrp         0.344087
# RAM_in_GB            0.295050
# free_delivery        0.147461
# number_of_reviews    0.044119
# bought_last_month    0.016288
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# free_delivery        1.000000
# bought_last_month    0.467738
# RAM_in_GB            0.403945
# original_mrp         0.332437
# storage_in_GB        0.307664
# number_of_reviews    0.203048
# discount%            0.147461
# rating_stars         0.143646
# Name: free_delivery, dtype: float64
#
# --- Correlations for Brand: samsung ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# number_of_reviews    0.524688
# original_mrp         0.315701
# bought_last_month    0.163607
# RAM_in_GB            0.083339
# free_delivery        0.067258
# storage_in_GB        0.046207
# rating_stars         0.006315
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# free_delivery        1.000000
# storage_in_GB        0.141308
# original_mrp         0.131919
# RAM_in_GB            0.080185
# discount%            0.067258
# number_of_reviews    0.063603
# bought_last_month    0.052521
# rating_stars         0.023494
# Name: free_delivery, dtype: float64
#
# --- Correlations for Brand: vivo ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# RAM_in_GB            0.638612
# original_mrp         0.595850
# storage_in_GB        0.566251
# number_of_reviews    0.462978
# bought_last_month    0.047534
# rating_stars         0.046394
# free_delivery        0.044241
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# free_delivery        1.000000
# rating_stars         0.278249
# storage_in_GB        0.120450
# original_mrp         0.114753
# discount%            0.044241
# bought_last_month    0.024493
# RAM_in_GB            0.017666
# number_of_reviews    0.013341
# Name: free_delivery, dtype: float64
#
# --- Correlations for Brand: xiaomi ---
#
# Correlations with 'discount%' (sorted in descending order):
# discount%            1.000000
# RAM_in_GB            0.343828
# storage_in_GB        0.282945
# original_mrp         0.173415
# bought_last_month    0.152502
# rating_stars         0.129910
# free_delivery        0.018191
# number_of_reviews    0.011578
# Name: discount%, dtype: float64
#
# Correlations with 'free_delivery' (sorted in descending order):
# free_delivery        1.000000
# rating_stars         0.108575
# number_of_reviews    0.085594
# original_mrp         0.074413
# discount%            0.018191
# bought_last_month    0.014457
# RAM_in_GB            0.012608
# storage_in_GB        0.004365
# Name: free_delivery, dtype: float64

# %%
df[df['brand'] == 'apple']['free_delivery'].value_counts()
# Out:
# free_delivery
# 0    129
# Name: count, dtype: int64

# %%
# List of feature columns to consider (excluding 'color', 'discount%' and 'free_delivery')
feature_columns = ['RAM_in_GB', 'storage_in_GB', 'number_of_reviews', 'rating_stars', 'original_mrp', 'bought_last_month']

# Initialize an empty dictionary to store selected features for each color
selected_features_by_color = {}

# Group by color and calculate correlations
for color, group in df.groupby('color'):
    # Calculate correlation matrix for the group
    correlations = group[feature_columns + ['discount%', 'free_delivery']].corr()

    # Get correlations with 'discount%' and 'free_delivery'
    discount_corr = correlations['discount%'].drop('discount%')  # Drop self-correlation
    free_delivery_corr = correlations['free_delivery'].drop('free_delivery')  # Drop self-correlation
    
    # Get the feature with the max absolute correlation for 'discount%'
    max_discount_corr_feature = discount_corr.abs().sort_values(ascending=False)  # Feature with highest abs correlation with discount%
    
    # Get the feature with the max absolute correlation for 'free_delivery'
    max_free_delivery_corr_feature = free_delivery_corr.abs().sort_values(ascending=False)  # Feature with highest abs correlation with free_delivery
    
    # Store the results in the dictionary
    selected_features_by_color[color] = {
        'max_discount_corr_feature': max_discount_corr_feature,
        'max_free_delivery_corr_feature': max_free_delivery_corr_feature
    }

# Print the selected features for each color
for color, features in selected_features_by_color.items():
    print(f"\n--- Selected Features for Color: {color} ---")
    print(f"Feature with max abs correlation to 'discount%': {features['max_discount_corr_feature']}")
    print(f"Feature with max abs correlation to 'free_delivery': {features['max_free_delivery_corr_feature']}")
# Out:
# --- Selected Features for Color: Black ---
# Feature with max abs correlation to 'discount%': bought_last_month    0.209302
# storage_in_GB        0.194591
# rating_stars         0.184024
# RAM_in_GB            0.157706
# original_mrp         0.129089
# number_of_reviews    0.059550
# free_delivery        0.042566
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': bought_last_month    0.206609
# RAM_in_GB            0.148507
# rating_stars         0.125653
# number_of_reviews    0.098575
# storage_in_GB        0.093283
# discount%            0.042566
# original_mrp         0.001621
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Black Titanium ---
# Feature with max abs correlation to 'discount%': RAM_in_GB            0.999343
# original_mrp         0.568125
# storage_in_GB        0.547383
# bought_last_month    0.547383
# rating_stars         0.432797
# number_of_reviews    0.261698
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Blue ---
# Feature with max abs correlation to 'discount%': rating_stars         0.365618
# bought_last_month    0.298290
# storage_in_GB        0.265477
# original_mrp         0.255368
# RAM_in_GB            0.128446
# number_of_reviews    0.095437
# free_delivery        0.093395
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': bought_last_month    0.378589
# original_mrp         0.338763
# storage_in_GB        0.199899
# rating_stars         0.118367
# number_of_reviews    0.099001
# discount%            0.093395
# RAM_in_GB            0.080448
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Blue Titanium ---
# Feature with max abs correlation to 'discount%': original_mrp         1.0
# storage_in_GB        1.0
# number_of_reviews    1.0
# rating_stars         1.0
# RAM_in_GB            NaN
# bought_last_month    NaN
# free_delivery        NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Desert Titanium ---
# Feature with max abs correlation to 'discount%': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# free_delivery       NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Gold ---
# Feature with max abs correlation to 'discount%': original_mrp         0.678455
# RAM_in_GB            0.497494
# storage_in_GB        0.492366
# free_delivery        0.369274
# rating_stars         0.360810
# number_of_reviews    0.252363
# bought_last_month    0.188141
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB            0.408248
# discount%            0.369274
# storage_in_GB        0.333333
# number_of_reviews    0.308844
# original_mrp         0.197043
# bought_last_month    0.152086
# rating_stars         0.049749
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Graphite ---
# Feature with max abs correlation to 'discount%': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# free_delivery       NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Gray ---
# Feature with max abs correlation to 'discount%': storage_in_GB        0.923866
# rating_stars         0.654667
# original_mrp         0.400939
# RAM_in_GB            0.278399
# bought_last_month    0.235905
# free_delivery        0.214399
# number_of_reviews    0.186103
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': original_mrp         0.516550
# RAM_in_GB            0.471405
# bought_last_month    0.455277
# rating_stars         0.424289
# storage_in_GB        0.416667
# discount%            0.214399
# number_of_reviews    0.184857
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Green ---
# Feature with max abs correlation to 'discount%': storage_in_GB        0.236670
# bought_last_month    0.194200
# original_mrp         0.188358
# rating_stars         0.174520
# RAM_in_GB            0.168789
# number_of_reviews    0.154182
# free_delivery        0.088926
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': bought_last_month    0.224411
# original_mrp         0.186019
# number_of_reviews    0.179693
# rating_stars         0.171639
# discount%            0.088926
# RAM_in_GB            0.085022
# storage_in_GB        0.035360
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Midnight ---
# Feature with max abs correlation to 'discount%': rating_stars         0.841113
# storage_in_GB        0.629268
# original_mrp         0.543643
# bought_last_month    0.145677
# number_of_reviews    0.064009
# RAM_in_GB                 NaN
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Natural Titanium ---
# Feature with max abs correlation to 'discount%': RAM_in_GB            0.995310
# original_mrp         0.515651
# bought_last_month    0.376192
# rating_stars         0.260261
# number_of_reviews    0.218851
# storage_in_GB        0.081413
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Pacific Blue ---
# Feature with max abs correlation to 'discount%': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# free_delivery       NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Pink ---
# Feature with max abs correlation to 'discount%': rating_stars         0.386571
# free_delivery        0.339560
# RAM_in_GB            0.234131
# number_of_reviews    0.221763
# bought_last_month    0.214291
# original_mrp         0.114514
# storage_in_GB        0.076824
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': rating_stars         0.870028
# RAM_in_GB            0.662994
# original_mrp         0.604866
# discount%            0.339560
# number_of_reviews    0.186387
# bought_last_month    0.148481
# storage_in_GB        0.099449
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Purple ---
# Feature with max abs correlation to 'discount%': original_mrp         0.731845
# rating_stars         0.642409
# storage_in_GB        0.552479
# bought_last_month    0.053916
# number_of_reviews    0.034159
# RAM_in_GB                 NaN
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Red ---
# Feature with max abs correlation to 'discount%': original_mrp         0.550933
# free_delivery        0.454421
# bought_last_month    0.330518
# number_of_reviews    0.178054
# storage_in_GB        0.086738
# RAM_in_GB            0.056249
# rating_stars         0.028518
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': original_mrp         0.687403
# discount%            0.454421
# bought_last_month    0.396657
# number_of_reviews    0.235853
# rating_stars         0.046251
# RAM_in_GB            0.034915
# storage_in_GB        0.027978
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Silver ---
# Feature with max abs correlation to 'discount%': rating_stars         0.843524
# storage_in_GB        0.446554
# RAM_in_GB            0.438755
# original_mrp         0.423333
# number_of_reviews    0.106328
# bought_last_month    0.103814
# free_delivery        0.054934
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB            0.440088
# bought_last_month    0.387321
# number_of_reviews    0.376162
# rating_stars         0.234126
# original_mrp         0.059845
# discount%            0.054934
# storage_in_GB        0.028904
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Space Black ---
# Feature with max abs correlation to 'discount%': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# free_delivery       NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Starlight ---
# Feature with max abs correlation to 'discount%': original_mrp         0.399179
# storage_in_GB        0.312908
# bought_last_month    0.212444
# number_of_reviews    0.192943
# rating_stars         0.100932
# RAM_in_GB                 NaN
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Teal ---
# Feature with max abs correlation to 'discount%': storage_in_GB        0.760726
# rating_stars         0.748455
# number_of_reviews    0.748455
# bought_last_month    0.476731
# original_mrp         0.457604
# RAM_in_GB                 NaN
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Ultramarine ---
# Feature with max abs correlation to 'discount%': storage_in_GB        0.745356
# bought_last_month    0.425918
# rating_stars         0.372678
# number_of_reviews    0.372678
# original_mrp         0.243975
# RAM_in_GB                 NaN
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: White ---
# Feature with max abs correlation to 'discount%': original_mrp         0.497042
# rating_stars         0.431447
# number_of_reviews    0.379455
# storage_in_GB        0.344282
# free_delivery        0.323137
# RAM_in_GB            0.269622
# bought_last_month    0.027362
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': original_mrp         0.405478
# discount%            0.323137
# rating_stars         0.164995
# number_of_reviews    0.158117
# RAM_in_GB            0.127796
# storage_in_GB        0.092593
# bought_last_month    0.067658
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: White Titanium ---
# Feature with max abs correlation to 'discount%': RAM_in_GB            1.000000
# rating_stars         0.975017
# original_mrp         0.853227
# number_of_reviews    0.624893
# storage_in_GB        0.583333
# bought_last_month    0.559017
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64
#
# --- Selected Features for Color: Yellow ---
# Feature with max abs correlation to 'discount%': number_of_reviews    0.806728
# original_mrp         0.646425
# storage_in_GB        0.615872
# rating_stars         0.529385
# bought_last_month    0.394798
# RAM_in_GB                 NaN
# free_delivery             NaN
# Name: discount%, dtype: float64
# Feature with max abs correlation to 'free_delivery': RAM_in_GB           NaN
# storage_in_GB       NaN
# number_of_reviews   NaN
# rating_stars        NaN
# original_mrp        NaN
# bought_last_month   NaN
# discount%           NaN
# Name: free_delivery, dtype: float64

# %% [markdown]
# # Applying Standardization and Min-Max Normalization

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Group by 'Brand' and plot correlation heatmap for each brand with scaling
for brand_name, group_data in df.groupby('brand'):
    # Select only numeric columns within each brand group
    numeric_data = group_data.select_dtypes(exclude=['object'])
    
    # Apply StandardScaler for Z-score normalization
    scaler = StandardScaler()  # Change to MinMaxScaler() for Min-Max scaling
    scaled_data = scaler.fit_transform(numeric_data)
    
    # Create a new DataFrame from the scaled data
    scaled_df = pd.DataFrame(scaled_data, columns=numeric_data.columns)
    
    # Calculate correlation matrix
    corr_matrix = scaled_df.corr()
    
    # Plot heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
    plt.title(f'Correlation Heatmap for {brand_name} (Scaled)')
    plt.show()

# %%
# Replace 'iphone' with 'apple' and 'redmi' with 'xiaomi'
df['brand'] = df['brand'].replace({'iphone': 'apple', 'redmi': 'xiaomi'})

# %%
numeric=df.select_dtypes(exclude=['object'])
# Apply StandardScaler for Z-score normalization
scaler = StandardScaler()  # Change to MinMaxScaler() for Min-Max scaling
scaled_data = scaler.fit_transform(numeric)

# Create a new DataFrame from the scaled data
scaled_df = pd.DataFrame(scaled_data, columns=numeric.columns)

# Calculate correlation matrix
corr_matrix = scaled_df.corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title(f'Correlation Heatmap for all (Scaled)')
plt.show()
